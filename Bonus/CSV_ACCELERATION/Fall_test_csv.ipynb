# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Change the path to the files for the code to work 
no_fall_01 = pd.read_csv("C:\\Users\\duham\\adl-01-acc.csv", names = ['time(ms)', 'SVtotal','Ax', 'Az','Ay'] )
no_fall_02 = pd.read_csv("C:\\Users\\duham\\adl-02-acc.csv", names = ['time(ms)', 'SVtotal','Ax', 'Az','Ay'] )
no_fall_03 = pd.read_csv("C:\\Users\\duham\\adl-03-acc.csv", names = ['time(ms)', 'SVtotal','Ax', 'Az','Ay'] )
no_fall_04 = pd.read_csv("C:\\Users\\duham\\adl-04-acc.csv", names = ['time(ms)', 'SVtotal','Ax', 'Az','Ay'] )
fall_01 = pd.read_csv("C:\\Users\\duham\\fall-01-acc.csv", names = ['time(ms)', 'SVtotal','Ax', 'Az','Ay'] )
fall_02 = pd.read_csv("C:\\Users\\duham\\fall-02-acc.csv", names = ['time(ms)', 'SVtotal','Ax', 'Az','Ay'] )
fall_03 = pd.read_csv("C:\\Users\\duham\\fall-03-acc.csv", names = ['time(ms)', 'SVtotal','Ax', 'Az','Ay'] )
fall_04 = pd.read_csv("C:\\Users\\duham\\fall-04-acc.csv", names = ['time(ms)', 'SVtotal','Ax', 'Az','Ay'] )

# %%
fall_01
# Out:
#      time(ms)   SVtotal        Ax        Az        Ay
# 0          -2  1.024924  0.128718  0.995601  0.206588
# 1          30  1.003218  0.166793  0.974967  0.167530
# 2          61  1.022040  0.175391  0.991916  0.172934
# 3          65  1.028459  0.152300  1.002479  0.171952
# 4          94  1.006250  0.139035  0.979880  0.181778
# ..        ...       ...       ...       ...       ...
# 188      5272  1.094388  0.064113 -0.351519  1.034413
# 189      5275  1.075617  0.094328 -0.346851  1.013779
# 190      5306  1.059123  0.147387 -0.293546  1.006901
# 191      5310  1.042477  0.182515 -0.286668  0.985529
# 192      5341  1.086908  0.196762 -0.367731  1.003707
#
# [193 rows x 5 columns]

# %%
plt.plot(no_fall_01['time(ms)'].to_numpy(), no_fall_01['SVtotal'].to_numpy())
plt.title("SVtotal as a function of time(ms)")
plt.xlabel("time(ms)")
plt.ylabel("SVtotal")
plt.show()

plt.plot(fall_01['time(ms)'].to_numpy(), fall_01['SVtotal'].to_numpy())
plt.title("SVtotal as a function of time(ms)")
plt.xlabel("time(ms)")
plt.ylabel("SVtotal")
plt.show()

# %%
Csv_test = fall_01

plt.plot(Csv_test['time(ms)'].to_numpy(), Csv_test['SVtotal'].to_numpy())
plt.title("SVtotal as a function of time(ms)")
plt.xlabel("time(ms)")
plt.ylabel("SVtotal")
plt.show()


test = False

for i in Csv_test['SVtotal'] :
    if i>2.9 :
        test = True

if test == True :
    print("Fall detected")
else :
    print("No Fall detected")
# Out:
# Fall detected

# %%
Csv_test = fall_02

plt.plot(Csv_test['time(ms)'].to_numpy(), Csv_test['SVtotal'].to_numpy())
plt.title("SVtotal as a function of time(ms)")
plt.xlabel("time(ms)")
plt.ylabel("SVtotal")
plt.show()


test = False

for i in Csv_test['SVtotal'] :
    if i>2.9 :
        test = True

if test == True :
    print("Fall detected")
else :
    print("No Fall detected")
# Out:
# Fall detected

# %%
Csv_test = no_fall_01

plt.plot(Csv_test['time(ms)'].to_numpy(), Csv_test['SVtotal'].to_numpy())
plt.title("SVtotal as a function of time(ms)")
plt.xlabel("time(ms)")
plt.ylabel("SVtotal")
plt.show()


test = False

for i in Csv_test['SVtotal'] :
    if i>2.9 :
        test = True

if test == True :
    print("Fall detected")
else :
    print("No Fall detected")
# Out:
# No Fall detected

# %%
Csv_test = no_fall_02

plt.plot(Csv_test['time(ms)'].to_numpy(), Csv_test['SVtotal'].to_numpy())
plt.title("SVtotal as a function of time(ms)")
plt.xlabel("time(ms)")
plt.ylabel("SVtotal")
plt.show()


test = False

for i in Csv_test['SVtotal'] :
    if i>2.9 :
        test = True

if test == True :
    print("Fall detected")
else :
    print("No Fall detected")
# Out:
# No Fall detected
